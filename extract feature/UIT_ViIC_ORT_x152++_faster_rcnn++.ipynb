# %% [markdown]
# ### Getting data

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
# !cp /content/gdrive/MyDrive/OpenViIC/UIT-ViIC/features/x152++_faster_rcnn.zip .

# %%
# !unzip x152++_faster_rcnn.zip -d features
# Out:
# Archive:  x152++_faster_rcnn.zip
#    creating: features/UIT-ViIC/
#    creating: features/UIT-ViIC/x152++_faster_rcnn/
#   inflating: features/UIT-ViIC/x152++_faster_rcnn/100034.npy
#   inflating: features/UIT-ViIC/x152++_faster_rcnn/100095.npy
#   inflating: features/UIT-ViIC/x152++_faster_rcnn/100222.npy
#   inflating: features/UIT-ViIC/x152++_faster_rcnn/100277.npy
#   inflating: features/UIT-ViIC/x152++_faster_rcnn/100344.npy
#   inflating: features/UIT-ViIC/x152++_faster_rcnn/100448.npy
#   inflating: features/UIT-ViIC/x152++_faster_rcnn/100454.npy
#   inflating: features/UIT-ViIC/x152++_faster_rcnn/100516.npy
#   inflating: features/UIT-ViIC/x152++_faster_rcnn/100519.npy
#   inflating: features/UIT-ViIC/x152++_faster_rcnn/100722.npy
#   inflating: features/UIT-ViIC/x152++_faster_rcnn/100865.npy
#   inflating: features/UIT-ViIC/x152++_faster_rcnn/10123.npy
#   inflating: features/UIT-ViIC/x152++_faster_rcnn/101243.npy
# ...

# %%
# !rm x152++_faster_rcnn.zip

# %%
# !mkdir annotations
# Out:
# mkdir: cannot create directory ‘annotations’: File exists

# %%
# !cp /content/gdrive/MyDrive/OpenViIC/UIT-ViIC/annotations/*.json annotations

# %% [markdown]
# ### Get the source code

# %%
# !git clone https://github.com/hieunghia-pat/OpenViIC.git
# Out:
# Cloning into 'OpenViIC'...
# remote: Enumerating objects: 2277, done.
# remote: Counting objects: 100% (338/338), done.
# remote: Compressing objects: 100% (92/92), done.
# remote: Total 2277 (delta 223), reused 310 (delta 210), pack-reused 1939
# Receiving objects: 100% (2277/2277), 204.34 MiB | 28.42 MiB/s, done.
# Resolving deltas: 100% (1513/1513), done.

# %%
cd OpenViIC
# Out:
# /content/OpenViIC

# %%
# !git checkout rstnet
# Out:
# Branch 'rstnet' set up to track remote branch 'rstnet' from 'origin'.
# Switched to a new branch 'rstnet'

# %% [markdown]
# ### Getting necessary libraries

# %%
# !pip3 install transformers yacs pyyaml --upgrade
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 5.8 MB 7.3 MB/s
# ...
#      |████████████████████████████████| 7.6 MB 57.6 MB/s
# ...
#      |████████████████████████████████| 182 kB 78.3 MB/s
# ...

# %% [markdown]
# ### Train model

# %%
# !mkdir saved_models

# %%
# !sh train_ort.sh
# Out:
# Namespace(annotation_folder='annotations', batch_size=60, exp_name='ort', features_path='features/UIT-ViIC/x152++_faster_rcnn', head=8, logs_folder='tensorboard_logs', m=40, resume_best=False, resume_last=False, warmup=10000, workers=2)
# Object Relation Transformer Training
# Training starts
# /usr/local/lib/python3.8/dist-packages/torch/optim/lr_scheduler.py:138: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn("Detected call of `lr_scheduler.step()` before `optimizer.step()`. "
# Epoch 0 - train: 100% 224/224 [00:50<00:00,  4.41it/s, loss=4.99]
# Epoch 0 - validation: 100% 77/77 [00:10<00:00,  7.01it/s, loss=3.32]
# ...

# %%
# !mkdir /content/gdrive/MyDrive/OpenViIC/UIT-ViIC/saved_models/ort_x152++_faster_rcnn

# %%
# !mv saved_models/* /content/gdrive/MyDrive/OpenViIC/UIT-ViIC/saved_models/ort_x152++_faster_rcnn

# %%
# !mv vocab_ort.pkl /content/gdrive/MyDrive/OpenViIC/UIT-ViIC/saved_models/ort_x152++_faster_rcnn
